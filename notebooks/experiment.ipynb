# %%
from task_scripts.input_source_1 import InputSource1
from task_scripts.input_source_2 import InputSource2
from task_scripts.input_source_3 import InputSource3
from vanilla_steel.database.models import Material

input_source = InputSource2("./resources/source2.xlsx")
df_dict = dict()
for sheet_name, df in input_source.read_data():
    df_dict[sheet_name] = input_source.restructure(sheet_name, df)
    print(sheet_name)
# Out:
# First choice
# 2nd choice

# %%
df_dict["First choice "]
# Out:
#    manufacturer_id material_name  ...                 file_path    sheet_name
# 0       2304/52068          None  ...  ./resources/source2.xlsx  First choice
# 0       2304/52068          None  ...  ./resources/source2.xlsx  First choice
# 0       2304/52068          None  ...  ./resources/source2.xlsx  First choice
# 1       2304/52075          None  ...  ./resources/source2.xlsx  First choice
# 1       2304/52075          None  ...  ./resources/source2.xlsx  First choice
# ..             ...           ...  ...                       ...           ...
# 11      2203/73892          None  ...  ./resources/source2.xlsx  First choice
# 12      2110/52027          None  ...  ./resources/source2.xlsx  First choice
# 13      2203/73915          None  ...  ./resources/source2.xlsx  First choice
# 14      2110/52010          None  ...  ./resources/source2.xlsx  First choice
# 15      2203/73922          None  ...  ./resources/source2.xlsx  First choice
#
# [89 rows x 18 columns]

# %%
df_dict["2nd choice "]
# Out:
#    manufacturer_id       material_name  ...                 file_path  sheet_name
# 1       2004/25542  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 2       2206/27940  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 3       2302/52583  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 4       2207/53700  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 5       2207/40892  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 6       2208/32436  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 7       2204/31998  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 8       2202/55501  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 9       2303/42482  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 10      2310/46181  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 11      2305/18290  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 17      2401/22326              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 18      2310/16948              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 19      2310/12230              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 20      2401/28601              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 21      2310/39305              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 22      2311/46386              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 23      2312/15389              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 24      2311/34840              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 25      2401/15304              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 29      2401/36811          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 30      2311/59379          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 31      2401/57274          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 32      2305/14209          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 33       2312/1924          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 34       2312/2013          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 35      2311/14200          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 36      2401/39744          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 37      2310/14357          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 38      2310/51079          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 39       2308/9008          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 40       2308/9015          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 41      2306/52468          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 42      2306/52475          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 43      2306/52482          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 44      2303/64064          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 45      2303/64071          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 46      2303/64088          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 47      2302/40764          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 48      2302/40849          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 49      2307/46143          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 50      2302/11771          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 51      2303/29834          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 52      2303/29858          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 53      2303/29865          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 54      2311/42746          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
#
# [46 rows x 18 columns]

# %%
import pandas as pd
from glob import glob

for file in glob("./resources/*.xlsx"):
    xls = pd.ExcelFile(file)
    for sheet_name in xls.sheet_names:
        print(f"file: {file}, sheet: {sheet_name}")
# Out:
# file: ./resources\source1.xlsx, sheet: Sheet1
# file: ./resources\source2.xlsx, sheet: First choice
# file: ./resources\source2.xlsx, sheet: 2nd choice
# file: ./resources\source3.xlsx, sheet: Feuil1

# %%
strength = ['RP02', 'RM', 'A', 'STA']
composition = ['AG', 'Al', 'Ars', 'B', 'C', 'Ca', 'Cr', 'S', 'Cu', 'Mn', 'Mo', 'N', 'Nb', 'Ni', 'P', 'Si', 'Sn', 'Ti', 'V', 'Zr']

def set_properties(row):
    def kv(row, keys):
        parts = []
        for key in keys:
            parts.append(f"{key}: {row[key]}")
        return "\n\t".join(parts)    
    props = [f"Grade: {row['Grade']}", f"Strength: \n\t{kv(row, strength)}", f"Chemical composition: \n\t{kv(row, composition)}"]
    return "\n".join(props)

def set_description(row):
    keys = ['Description', 'Finish']
    parts = []
    for key in keys:
        parts.append(f"{key}: {row[key]}")
    return "\n".join(parts)

file_path = "./resources/source1.xlsx"
sheet_name = "Sheet1"
df = pd.read_excel(file_path, sheet_name=sheet_name)

# cleaning
df["Finish"] = df["Finish"].str.replace("ungebeizt, nicht geglüht", "Unpickled, Not Annealed")
df["Finish"] = df["Finish"].str.replace("gebeizt und geglüht", "Pickled and Annealed")

df["Description"] = df["Description"].str.replace('Sollmasse (Gewicht) unterschritten', "Below target weight")
df["Description"] = df["Description"].str.replace('Kantenfehler - FS-Kantenrisse', "Edge defects - FS edge cracks")
df["Description"] = df["Description"].str.replace('Längs- oder Querrisse', "Longitudinal or transverse cracks")

df["properties"] = df.apply(set_properties, axis=1)
df["Description"] = df.apply(set_description, axis=1)
df.drop(columns=["Finish"] + strength + composition, inplace=True)
df["file_path"] = file_path
df["sheet_name"] = sheet_name

df.columns = [col.lower().strip().replace(" ","_") for col in df.columns]
df.rename(columns={"quality/choice": "choice", "grade": "material_name", "thickness_(mm)": "height", "width_(mm)": "breadth", "gross_weight_(kg)": "weight"}, inplace=True)
df["choice"] = df["choice"].str.replace("2nd", "2")
df["choice"] = df["choice"].fillna("-1")
df["choice"] = df["choice"].astype(int)

df['length'] = None
df["quantity_unit"] = "piece"
df["dimension_unit"] = "mm" 
df["weighing_unit"] = "kg"

df["quantity"] = None
df["material_id"] = None
df["total_price"] = None
df["price_per_unit"] = None
df["supplier"] = None
df["reserved"] = None

df = df.reindex(columns=['material_id', 'material_name', 'quantity', 'quantity_unit', 'price_per_unit', 'supplier', 'length', 'breadth', 'height', 'dimension_unit', 'weight', 'weighing_unit', 'properties', 'description', 'choice', 'reserved'])
df
# Out:
#    material_id material_name  ... choice reserved
# 0         None         C100S  ...      2     None
# 1         None         C100S  ...      2     None
# 2         None         C100S  ...      2     None
# 3         None         C100S  ...      2     None
# 4         None         C100S  ...      2     None
# 5         None         C100S  ...      2     None
# 6         None         C100S  ...      2     None
# 7         None         C100S  ...      2     None
# 8         None         C100S  ...      2     None
# 9         None         C100S  ...      2     None
# 10        None         C100S  ...      2     None
# 11        None         C100S  ...      2     None
# 12        None         C100S  ...      2     None
# 13        None         C100S  ...      2     None
# 14        None         C100S  ...      2     None
# 15        None         C100S  ...      2     None
# 16        None         C100S  ...      2     None
# 17        None         C100S  ...      2     None
# 18        None         C100S  ...      2     None
# 19        None         C100S  ...      2     None
# 20        None         C100S  ...      2     None
# 21        None         C100S  ...      2     None
# 22        None         C100S  ...      2     None
# 23        None         C100S  ...      2     None
# 24        None         C100S  ...      2     None
# 25        None         C100S  ...      2     None
# 26        None         C100S  ...      2     None
# 27        None         C100S  ...      2     None
# 28        None         C100S  ...      2     None
# 29        None         C100S  ...      2     None
# 30        None         C100S  ...      2     None
# 31        None         C100S  ...      2     None
# 32        None         C100S  ...      2     None
# 33        None         C100S  ...      2     None
# 34        None           NaN  ...     -1     None
#
# [35 rows x 16 columns]

# %%
import re

pattern = r'(?P<length>\d{1,2}(?:[,.]\d{2})?) x (?P<breadth>\d{1,4}(?:[,.]\d{2})?)(?: x (?P<height>\d{1,4}(?:[,.]\d{2})?))?(?: (?P<dimension_unit>mm))?'
    
def extract_dimensions(text):
    match = re.search(pattern, text)
    if match:
        return match.groupdict()
    return {"length": None, "breadth": None, "height": None, "dimension_unit": None}

# %%
import pandas as pd

file_path = "./resources/source2.xlsx"
sheet_name = "First choice "
df = pd.read_excel(file_path, sheet_name=sheet_name)
# df1
df1 = df.iloc[1:12]
df1.columns = df.iloc[0].tolist()
df1.reset_index(drop=True, inplace=True)
# df2
df2 = df.iloc[15:23]
df2.columns = df.iloc[14].tolist()
df2.reset_index(drop=True, inplace=True)
# df3
df3 = df.iloc[26:]
df3.columns = df.iloc[25].tolist()
df3.reset_index(drop=True, inplace=True)
df3 = df3.dropna(axis=1, how='all')
# cleaning
df = pd.concat([df1, df2, df3])
df.columns = [col.lower().strip().replace(" ","_") for col in df.columns]
df.rename(columns={"article_id": "material_id", "material": "properties", "description": "other_description", "opmerking": "description"}, inplace=True)
df["description"] = df["description"].fillna("")
df["properties"] = df.apply(lambda row: row["properties"] + " Oiled" if str(row["other_description"]).strip()=="Material is Oiled" else row["properties"], axis=1)
df.drop(columns=["other_description"], inplace=True)
df["properties"] = df["properties"].str.replace(r'(\d)x', r'\1 x ', regex=True)
df = df.join(df["properties"].apply(extract_dimensions).apply(pd.Series))
df["dimension_unit"] = df["dimension_unit"].fillna("mm")
df["properties"] = df["properties"].str.replace(r'(\w)\+', r'\1 +', regex=True)
df["properties"] = df["properties"].str.replace(r'(\d)mm', r'\1 mm', regex=True)
df["properties"] = df["properties"].str.replace(pattern, '', regex=True)
df["properties"] = df["properties"].apply(lambda x: x.replace("geolied", "Oiled"))
df["quantity_unit"] = "piece"
df["total_price"] = None
df["price_per_unit"] = None
df["supplier"] = None
df["weighing_unit"] = None
df["choice"] = 1
df = df.reindex(columns=['material_id', 'material_name', 'quantity', 'quantity_unit', 'price_per_unit', 'supplier', 'length', 'breadth', 'height', 'dimension_unit', 'weight', 'weighing_unit', 'properties', 'description', 'choice', 'reserved'])
df["file_path"] = file_path.replace('\\', '/')
df["sheet_name"] = sheet_name.strip()
df
# Out:
#    material_id  material_name  ...                 file_path    sheet_name
# 0   2304/52068            NaN  ...  ./resources/source2.xlsx  First choice
# 0   2304/52068            NaN  ...  ./resources/source2.xlsx  First choice
# 0   2304/52068            NaN  ...  ./resources/source2.xlsx  First choice
# 1   2304/52075            NaN  ...  ./resources/source2.xlsx  First choice
# 1   2304/52075            NaN  ...  ./resources/source2.xlsx  First choice
# ..         ...            ...  ...                       ...           ...
# 11  2203/73892            NaN  ...  ./resources/source2.xlsx  First choice
# 12  2110/52027            NaN  ...  ./resources/source2.xlsx  First choice
# 13  2203/73915            NaN  ...  ./resources/source2.xlsx  First choice
# 14  2110/52010            NaN  ...  ./resources/source2.xlsx  First choice
# 15  2203/73922            NaN  ...  ./resources/source2.xlsx  First choice
#
# [89 rows x 18 columns]

# %%
df["material_id"].count(), df["material_id"].drop_duplicates().count()
# Out:
# (89, 35)

# %%
import pandas as pd

file_path= "./resources/source2.xlsx"
sheet_name = "2nd choice "
df = pd.read_excel(file_path, sheet_name=sheet_name)
material_name1 = str(df.columns[0]).strip()
material_name2 = str(df.iloc[15, 0]).strip()
material_name3 = str(df.iloc[27, 0]).strip()
print(f"{material_name1}, {material_name2}, {material_name3}")
df.columns = df.iloc[0].tolist()
df = df.drop(index=0)
df["material_name"] = None
df.loc[0:12, "material_name"] = material_name1
df.loc[17:25, "material_name"] = material_name2
df.loc[29:, "material_name"] = material_name3
df = df.dropna(axis=0, how='all')
df.drop(index=[12, 15, 16, 27, 28], inplace=True)
df.columns = [col.lower().strip().replace(" ","_") for col in df.columns]
df.rename(columns={"article_id": "material_id", "material": "properties", "defect_description": "description"}, inplace=True)
df["properties"] = df["properties"].str.replace('*', 'x')
df["properties"] = df["properties"].str.replace(r'(\d)x', r'\1 x ', regex=True)
df = df.join(df["properties"].apply(extract_dimensions).apply(pd.Series))
df["dimension_unit"] = df["dimension_unit"].fillna("mm")
df["properties"] = df["properties"].str.replace(r'(\w)\+', r'\1 +', regex=True)
df["properties"] = df["properties"].str.replace(r'(\d)mm', r'\1 mm', regex=True)
df["properties"] = df["properties"].str.replace(pattern, '', regex=True)
df["properties"] = df["properties"].apply(lambda x: x.replace("licht geolied", "Little-Oiled"))
df["properties"] = df["properties"].apply(lambda x: x.replace("geolied", "Oiled"))
df["description"] = df.apply(lambda row: row["description"] if "ongeb/ ongeol traan" not in row["properties"] else row["description"] + " ongeb/ ongeol traan", axis=1)
df["description"] = df["description"].fillna("")
df["properties"] = df["properties"].apply(lambda x: x.replace("ongeb/ ongeol traan", ""))
df["properties"] = df["properties"].apply(lambda x: x.replace("MAC", "Ma-C"))
df["quantity_unit"] = "piece"
df["total_price"] = None
df["price_per_unit"] = None
df["supplier"] = None
df["weighing_unit"] = None
df["choice"] = 2
df["reserved"] = None
df = df.reindex(columns=['material_id', 'material_name', 'quantity', 'quantity_unit', 'price_per_unit', 'supplier', 'length', 'breadth', 'height', 'dimension_unit', 'weight', 'weighing_unit', 'properties', 'description', 'choice', 'reserved'])
df["file_path"] = file_path.replace('\\', '/')
df["sheet_name"] = sheet_name.strip()
df
# Out:
# Baby Coils & Coils, Sheets, Slit Coils
#    material_id       material_name  ...                 file_path  sheet_name
# 1   2004/25542  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 2   2206/27940  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 3   2302/52583  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 4   2207/53700  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 5   2207/40892  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 6   2208/32436  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 7   2204/31998  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 8   2202/55501  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 9   2303/42482  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 10  2310/46181  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 11  2305/18290  Baby Coils & Coils  ...  ./resources/source2.xlsx  2nd choice
# 17  2401/22326              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 18  2310/16948              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 19  2310/12230              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 20  2401/28601              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 21  2310/39305              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 22  2311/46386              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 23  2312/15389              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 24  2311/34840              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 25  2401/15304              Sheets  ...  ./resources/source2.xlsx  2nd choice
# 29  2401/36811          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 30  2311/59379          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 31  2401/57274          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 32  2305/14209          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 33   2312/1924          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 34   2312/2013          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 35  2311/14200          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 36  2401/39744          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 37  2310/14357          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 38  2310/51079          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 39   2308/9008          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 40   2308/9015          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 41  2306/52468          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 42  2306/52475          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 43  2306/52482          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 44  2303/64064          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 45  2303/64071          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 46  2303/64088          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 47  2302/40764          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 48  2302/40849          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 49  2307/46143          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 50  2302/11771          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 51  2303/29834          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 52  2303/29858          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 53  2303/29865          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
# 54  2311/42746          Slit Coils  ...  ./resources/source2.xlsx  2nd choice
#
# [46 rows x 18 columns]

# %%
df[df["description"].str.contains("ongeb/ ongeol traan")]["description"].tolist()
# Out:
# ['Tension  actualy fisrt choice - Teardrop Coil thickness 5 - 7mm ongeb/ ongeol traan']

# %%
df["material_id"].count(), df["material_id"].drop_duplicates().count()
# Out:
# (46, 46)

# %%
df.iloc[9, -1]
# Out:
# '2nd choice'

# %%
file_path = "./resources\source3.xlsx"
sheet_name = "Feuil1"
df = pd.read_excel(file_path, sheet_name=sheet_name)
df.columns = [col.lower().strip().replace(" ","_") for col in df.columns]
df.rename(columns={"numéro_de": "material_id", "article": "material_name", "matériel_desc#": "properties", "unité": "weighing_unit", "libre": "weight"}, inplace=True)
df["properties"] = df["properties"].str.replace('*', 'x')
df["properties"] = df["properties"].str.replace(r'(\d)x', r'\1 x ', regex=True)
df = df.join(df["properties"].apply(extract_dimensions).apply(pd.Series))
df["dimension_unit"] = df["dimension_unit"].fillna("mm")
df["properties"] = df["properties"].str.replace(r'(\w)\+', r'\1 +', regex=True)
df["properties"] = df["properties"].str.replace(r'(\d)mm', r'\1 mm', regex=True)
df["properties"] = df["properties"].str.replace('+Z 140', '+Z140')
df["properties"] = df["properties"].str.replace(pattern, '', regex=True)
df["description"] = ""

df["quantity"] = None
df["quantity_unit"] = None

df["price_per_unit"] = None
df["supplier"] = None

df["choice"] = -1
df["reserved"] = None
df = df.reindex(columns=['material_id', 'material_name', 'quantity', 'quantity_unit', 'price_per_unit', 'supplier', 'length', 'breadth', 'height', 'dimension_unit', 'weight', 'weighing_unit', 'properties', 'description', 'choice', 'reserved'])
df["file_path"] = file_path.replace('\\', '/')
df["sheet_name"] = sheet_name.strip()

df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\praveer kumar\AppData\Local\Temp\ipykernel_3488\1031677633.py:1: SyntaxWarning: invalid escape sequence '\s'
#   file_path = "./resources\source3.xlsx"
#     material_id  material_name  ...                 file_path sheet_name
# 0       2231027       11006841  ...  ./resources/source3.xlsx     Feuil1
# 1       2253917       11006841  ...  ./resources/source3.xlsx     Feuil1
# 2       2141400       11006843  ...  ./resources/source3.xlsx     Feuil1
# 3       2176549       11006843  ...  ./resources/source3.xlsx     Feuil1
# 4       2144362       11006915  ...  ./resources/source3.xlsx     Feuil1
# 5       2193183       11007024  ...  ./resources/source3.xlsx     Feuil1
# 6       2376477       11007031  ...  ./resources/source3.xlsx     Feuil1
# 7       2389800       11007136  ...  ./resources/source3.xlsx     Feuil1
# 8       2153593       11007240  ...  ./resources/source3.xlsx     Feuil1
# 9       2112436       11007347  ...  ./resources/source3.xlsx     Feuil1
# 10      2112439       11007347  ...  ./resources/source3.xlsx     Feuil1
# 11      2165168       11007462  ...  ./resources/source3.xlsx     Feuil1
# 12      2121522       11007896  ...  ./resources/source3.xlsx     Feuil1
# 13      2165165       11007912  ...  ./resources/source3.xlsx     Feuil1
# 14      2165166       11007912  ...  ./resources/source3.xlsx     Feuil1
# 15      2165167       11007912  ...  ./resources/source3.xlsx     Feuil1
# 16      2306268       11007912  ...  ./resources/source3.xlsx     Feuil1
# 17      2328817       11007912  ...  ./resources/source3.xlsx     Feuil1
# 18      2330687       11007912  ...  ./resources/source3.xlsx     Feuil1
# 19      2197778       11010359  ...  ./resources/source3.xlsx     Feuil1
# 20      2160789       11011779  ...  ./resources/source3.xlsx     Feuil1
# 21      2231858       11011808  ...  ./resources/source3.xlsx     Feuil1
# 22      2135022       11015501  ...  ./resources/source3.xlsx     Feuil1
# 23      2231511       11015537  ...  ./resources/source3.xlsx     Feuil1
# 24      2134770       11016868  ...  ./resources/source3.xlsx     Feuil1
# 25      2177728       11018437  ...  ./resources/source3.xlsx     Feuil1
# 26      2141151       11020045  ...  ./resources/source3.xlsx     Feuil1
# 27      1810123       13012123  ...  ./resources/source3.xlsx     Feuil1
# 28      1810363       13012123  ...  ./resources/source3.xlsx     Feuil1
# 29      1810566       13012123  ...  ./resources/source3.xlsx     Feuil1
# 30      1810811       13012123  ...  ./resources/source3.xlsx     Feuil1
# 31      1810917       13012123  ...  ./resources/source3.xlsx     Feuil1
# 32      1811070       13012123  ...  ./resources/source3.xlsx     Feuil1
# 33      1811102       13012123  ...  ./resources/source3.xlsx     Feuil1
# 34      2220957       13013020  ...  ./resources/source3.xlsx     Feuil1
# 35      2100653       13015079  ...  ./resources/source3.xlsx     Feuil1
# 36      2100660       13015079  ...  ./resources/source3.xlsx     Feuil1
# 37      2372614       13015114  ...  ./resources/source3.xlsx     Feuil1
# 38      2266008       13015118  ...  ./resources/source3.xlsx     Feuil1
# 39       585442       13015500  ...  ./resources/source3.xlsx     Feuil1
# 40      1905346       13030650  ...  ./resources/source3.xlsx     Feuil1
# 41      2249852       13031256  ...  ./resources/source3.xlsx     Feuil1
# 42      1967587       20000008  ...  ./resources/source3.xlsx     Feuil1
# 43      1967588       20000008  ...  ./resources/source3.xlsx     Feuil1
# 44      1967662       20000008  ...  ./resources/source3.xlsx     Feuil1
# 45      2141622       20000036  ...  ./resources/source3.xlsx     Feuil1
# 46      2141631       20000036  ...  ./resources/source3.xlsx     Feuil1
# 47      2141644       20000036  ...  ./resources/source3.xlsx     Feuil1
# 48      2089220       36000012  ...  ./resources/source3.xlsx     Feuil1
# 49      2095720       36000105  ...  ./resources/source3.xlsx     Feuil1
# 50      2284239       36000107  ...  ./resources/source3.xlsx     Feuil1
# 51      2292729       36000107  ...  ./resources/source3.xlsx     Feuil1
# 52      2235139       36000114  ...  ./resources/source3.xlsx     Feuil1
# 53      2237593       36000114  ...  ./resources/source3.xlsx     Feuil1
# 54      2118606       36000274  ...  ./resources/source3.xlsx     Feuil1
# 55      2221582       36000697  ...  ./resources/source3.xlsx     Feuil1
#
# [56 rows x 18 columns]
